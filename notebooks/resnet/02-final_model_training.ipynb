# %% [markdown]
# # Final ResNet training
#
# This notebook defines paths and delegates final training to the controller API.

# %%
from pathlib import Path
import sys

from pyprojroot import here

PROJECT_ROOT = Path(here())
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from ml_training_lab.controller.resnet_training_controller import train_final_resnet  # noqa: E402
from ml_training_lab.presentation.requests import ResNetRequest  # noqa: E402

# %%
CONFIG_PATH = PROJECT_ROOT / "config/resnet_training.json"
DATASET_PATH = PROJECT_ROOT / "data/meta/interim/metadata_augmented.parquet"
IMAGE_ROOT = PROJECT_ROOT / "data/images"

request = ResNetRequest(
    project_root=PROJECT_ROOT,
    config_path=CONFIG_PATH,
    dataset_path=DATASET_PATH,
    image_root=IMAGE_ROOT,
)
request
# Out:
# ResNetRequest(project_root=PosixPath('/Users/locked15/Repos.localized/Python/Study/UUST/Course 3/Semester 2/Practice/sludge-utilities/apps/ml/ml-training_lab'), config_path=PosixPath('/Users/locked15/Repos.localized/Python/Study/UUST/Course 3/Semester 2/Practice/sludge-utilities/apps/ml/ml-training_lab/config/resnet_training.json'), dataset_path=PosixPath('/Users/locked15/Repos.localized/Python/Study/UUST/Course 3/Semester 2/Practice/sludge-utilities/apps/ml/ml-training_lab/data/meta/interim/metadata_augmented.parquet'), image_root=PosixPath('/Users/locked15/Repos.localized/Python/Study/UUST/Course 3/Semester 2/Practice/sludge-utilities/apps/ml/ml-training_lab/data/images'))

# %%
result = train_final_resnet(request)

print(f"Run directory: {result.run_dir}")
print(f"Final model saved to: {result.model_path}")
print(result.metrics)
# Out:
# Seed set to 42
# ...
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# /Users/locked15/Repos.localized/Python/Study/UUST/Course 3/Semester 2/Practice/sludge-utilities/apps/ml/ml-training_lab/.venv/lib/python3.12/site-packages/pytorch_lightning/trainer/configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
# ┏━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name      ┃ Type       ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ backbone  │ ResNet     │ 23.5 M │ train │     0 │
# │ 1 │ head      │ Sequential │  1.1 M │ train │     0 │
# │ 2 │ criterion │ HuberLoss  │      0 │ train │     0 │
# ...
