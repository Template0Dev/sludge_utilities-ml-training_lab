# %% [markdown]
# # Overview
#
# Load an explicit Optuna summary, refit on wells 2–4, and evaluate once on original samples from holdout well 1.

# %% [markdown]
# ## 1. Imports

# %%
import sys
from pathlib import Path

from pyprojroot import here

PROJECT_ROOT = Path(here())
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from ml_training_lab.resnet_workflow import ResNetFinalConfig, train_final_resnet

# %% [markdown]
# ## 2. Config

# %%
OPTUNA_SUMMARY_PATH = PROJECT_ROOT / "output/resnet/optuna/resnet_macro_mae_v1_summary.json"

config = ResNetFinalConfig(
    project_root=PROJECT_ROOT,
    optuna_summary_path=OPTUNA_SUMMARY_PATH,
)

# %% [markdown]
# ## 3. Training Pipeline

# %%
model_path, training_metadata = train_final_resnet(config)
print(f"Final model saved to: {model_path}")
print(training_metadata["final_training_metrics"])
