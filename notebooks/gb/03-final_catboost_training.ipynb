# %% [markdown]
# # Final CatBoost training
#
# This notebook defines paths and delegates final training to the controller API.

# %%
from pathlib import Path
import sys

from pyprojroot import here

PROJECT_ROOT = Path(here())
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from ml_training_lab.controller.catboost_training_controller import train_final_catboost  # noqa: E402
from ml_training_lab.presentation.requests import CatBoostRequest  # noqa: E402

# %%
CONFIG_PATH = PROJECT_ROOT / "config/gb_training.json"
BASE_DATASET_PATH = PROJECT_ROOT / "data/meta/interim/metadata_augmented.parquet"
EMBEDDING_DATASET_PATH = PROJECT_ROOT / "data/meta/processed/gb/metadata_dinov3_embeddings.parquet"

request = CatBoostRequest(
    project_root=PROJECT_ROOT,
    config_path=CONFIG_PATH,
    base_dataset_path=BASE_DATASET_PATH,
    embedding_dataset_path=EMBEDDING_DATASET_PATH,
)
request
# Out:
# CatBoostRequest(project_root=PosixPath('/Users/locked15/Repos.localized/Python/Study/UUST/Course 3/Semester 2/Practice/sludge-utilities/apps/ml/ml-training_lab'), config_path=PosixPath('/Users/locked15/Repos.localized/Python/Study/UUST/Course 3/Semester 2/Practice/sludge-utilities/apps/ml/ml-training_lab/config/gb_training.json'), base_dataset_path=PosixPath('/Users/locked15/Repos.localized/Python/Study/UUST/Course 3/Semester 2/Practice/sludge-utilities/apps/ml/ml-training_lab/data/meta/interim/metadata_augmented.parquet'), embedding_dataset_path=PosixPath('/Users/locked15/Repos.localized/Python/Study/UUST/Course 3/Semester 2/Practice/sludge-utilities/apps/ml/ml-training_lab/data/meta/processed/gb/metadata_dinov3_embeddings.parquet'))

# %%
result = train_final_catboost(request)

print(f"Run directory: {result.run_dir}")
print(f"Final model saved to: {result.model_path}")
print(result.metrics)
# Out:
# Run directory: /Users/locked15/Repos.localized/Python/Study/UUST/Course 3/Semester 2/Practice/sludge-utilities/apps/ml/ml-training_lab/output/gb/runs/1f17383e-7e6a-67e0-9e38-398241552ab7
# Final model saved to: /Users/locked15/Repos.localized/Python/Study/UUST/Course 3/Semester 2/Practice/sludge-utilities/apps/ml/ml-training_lab/output/gb/runs/1f17383e-7e6a-67e0-9e38-398241552ab7/model.cbm
# {'macro_mae': 8.60170393524598, 'target_mae': {'sandstone_sludge': 8.913666974444755, 'siltstone_sludge': 8.795422260294348, 'argillite_sludge': 8.096022570998839}, 'per_target': {'sandstone_sludge': {'mae': 8.913666974444755, 'rmse': 11.080470862872254, 'r2': 0.9023176924630893}, 'siltstone_sludge': {'mae': 8.795422260294348, 'rmse': 10.311370501576125, 'r2': 0.3908049527423769}, 'argillite_sludge': {'mae': 8.096022570998839, 'rmse': 10.339046044428578, 'r2': 0.8117088868987159}}}
