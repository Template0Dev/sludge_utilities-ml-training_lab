# %% [markdown]
# # Overview
#
# Load the configured Optuna summary, fit PCA and CatBoost on the configured training wells, and evaluate once on original samples from the target well.

# %% [markdown]
# ## 1. Imports

# %%
import sys
from pathlib import Path

from pyprojroot import here

PROJECT_ROOT = Path(here())
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from ml_training_lab.gb_workflow import GBFinalConfig, train_final_catboost

# %% [markdown]
# ## 2. Config

# %%
CONFIG_PATH = PROJECT_ROOT / "config/gb_training.json"

config = GBFinalConfig.from_file(PROJECT_ROOT, CONFIG_PATH)

# %% [markdown]
# ## 3. Training Pipeline

# %%
model_path, training_metadata = train_final_catboost(config)
print(f"Final model saved to: {model_path}")
print(training_metadata["final_training_metrics"])
# Out:
# Final model saved to: /Users/locked15/Repos.localized/Python/Study/UUST/Course 3/Semester 2/Practice/sludge-utilities/apps/ml/ml-training_lab/output/gb/models/[1f171714-f2f9-65ca-abc3-147f01d0b907] CatBoost.cbm
# {'macro_mae': 7.398167434596101, 'target_mae': {'sandstone_sludge': 8.348653976638891, 'siltstone_sludge': 7.647158599555353, 'argillite_sludge': 6.1986897275940605}, 'per_target': {'sandstone_sludge': {'mae': 8.348653976638891, 'rmse': 10.57420267032879, 'r2': -0.3148761740358301}, 'siltstone_sludge': {'mae': 7.647158599555353, 'rmse': 11.885591278253628, 'r2': 0.23512743407168668}, 'argillite_sludge': {'mae': 6.1986897275940605, 'rmse': 7.905125504264672, 'r2': 0.4028222360960795}}}
