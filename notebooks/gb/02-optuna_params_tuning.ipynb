# %% [markdown]
# # CatBoost Optuna tuning
#
# This notebook defines paths and delegates tuning to the controller API.

# %%
from pathlib import Path
import sys

from pyprojroot import here

PROJECT_ROOT = Path(here())
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from ml_training_lab.controller.catboost_tuning_controller import tune_catboost  # noqa: E402
from ml_training_lab.presentation.requests import CatBoostRequest  # noqa: E402

# %%
CONFIG_PATH = PROJECT_ROOT / "config/gb_training.json"
BASE_DATASET_PATH = PROJECT_ROOT / "data/meta/interim/metadata_augmented.parquet"
EMBEDDING_DATASET_PATH = PROJECT_ROOT / "data/meta/processed/gb/metadata_dinov3_embeddings.parquet"

request = CatBoostRequest(
    project_root=PROJECT_ROOT,
    config_path=CONFIG_PATH,
    base_dataset_path=BASE_DATASET_PATH,
    embedding_dataset_path=EMBEDDING_DATASET_PATH,
)
request
# Out:
# CatBoostRequest(project_root=PosixPath('/Users/locked15/Repos.localized/Python/Study/UUST/Course 3/Semester 2/Practice/sludge-utilities/apps/ml/ml-training_lab'), config_path=PosixPath('/Users/locked15/Repos.localized/Python/Study/UUST/Course 3/Semester 2/Practice/sludge-utilities/apps/ml/ml-training_lab/config/gb_training.json'), base_dataset_path=PosixPath('/Users/locked15/Repos.localized/Python/Study/UUST/Course 3/Semester 2/Practice/sludge-utilities/apps/ml/ml-training_lab/data/meta/interim/metadata_augmented.parquet'), embedding_dataset_path=PosixPath('/Users/locked15/Repos.localized/Python/Study/UUST/Course 3/Semester 2/Practice/sludge-utilities/apps/ml/ml-training_lab/data/meta/processed/gb/metadata_dinov3_embeddings.parquet'))

# %%
result = tune_catboost(request)
print(f"Tune id: {result.tune_id}")
print(f"Tune directory: {result.tune_dir}")
print(f"Optuna summary saved to: {result.summary_path}")
print(f"Optuna trials saved to: {result.trials_path}")
print(f"Optuna database: {result.study_database_path}")
# Out:
# [I 2026-07-02 00:55:09,422] A new study created in RDB with name: catboost_dataset_split_v1
# [I 2026-07-02 00:55:10,313] Trial 0 finished with value: 14.024631422336048 and parameters: {'pca_components': 32, 'learning_rate': 0.015, 'depth': 5, 'l2_leaf_reg': 10.0, 'subsample': 0.8, 'rsm': 0.7, 'random_strength': 1.0}. Best is trial 0 with value: 14.024631422336048.
# [I 2026-07-02 00:55:11,617] Trial 1 finished with value: 13.707703188795614 and parameters: {'pca_components': 32, 'learning_rate': 0.007979118876474874, 'depth': 5, 'l2_leaf_reg': 1.218418650222176, 'subsample': 0.9330880728874675, 'rsm': 0.8005575058716043, 'random_strength': 0.6796578090758157}. Best is trial 1 with value: 13.707703188795614.
# [I 2026-07-02 00:55:12,711] Trial 2 finished with value: 14.340958402119805 and parameters: {'pca_components': 32, 'learning_rate': 0.008620446097910767, 'depth': 5, 'l2_leaf_reg': 2.8145092716060645, 'subsample': 0.762378215816119, 'rsm': 0.7159725093210578, 'random_strength': 0.014618962793704969}. Best is trial 1 with value: 13.707703188795614.
# [I 2026-07-02 00:55:15,746] Trial 3 finished with value: 12.147173966546086 and parameters: {'pca_components': 16, 'learning_rate': 0.019603369861210685, 'depth': 9, 'l2_leaf_reg': 1.9721610970573997, 'subsample': 0.7571172192068059, 'rsm': 0.7962072844310213, 'random_strength': 0.0015339162591163618}. Best is trial 3 with value: 12.147173966546086.
# [I 2026-07-02 00:55:21,222] Trial 4 finished with value: 13.931679076945978 and parameters: {'pca_components': 128, 'learning_rate': 0.09021655603568132, 'depth': 9, 'l2_leaf_reg': 2.8180680291847233, 'subsample': 0.5488360570031919, 'rsm': 0.8421165132560784, 'random_strength': 0.057624872164786005}. Best is trial 3 with value: 12.147173966546086.
# [I 2026-07-02 00:55:31,432] Trial 5 finished with value: 13.198673710975482 and parameters: {'pca_components': 128, 'learning_rate': 0.010855517271883068, 'depth': 8, 'l2_leaf_reg': 2.8869220380495735, 'subsample': 0.7600340105889054, 'rsm': 0.7733551396716398, 'random_strength': 0.0054880470007660455}. Best is trial 3 with value: 12.147173966546086.
# [I 2026-07-02 00:55:37,874] Trial 6 finished with value: 11.930558625612477 and parameters: {'pca_components': 16, 'learning_rate': 0.0299816694120633, 'depth': 10, 'l2_leaf_reg': 1.3511829476450818, 'subsample': 0.5979914312095727, 'rsm': 0.522613644455269, 'random_strength': 0.02001342062287998}. Best is trial 6 with value: 11.930558625612477.
# [I 2026-07-02 00:55:46,985] Trial 7 pruned. Pruned after validation-well validation
# [I 2026-07-02 00:55:54,734] Trial 8 finished with value: 13.394228103080351 and parameters: {'pca_components': 128, 'learning_rate': 0.04155397855708038, 'depth': 9, 'l2_leaf_reg': 13.780336485751999, 'subsample': 0.5370223258670452, 'rsm': 0.6792328642721364, 'random_strength': 0.0029072088906598446}. Best is trial 6 with value: 11.930558625612477.
# [I 2026-07-02 00:55:56,114] Trial 9 finished with value: 12.599541247790292 and parameters: {'pca_components': 16, 'learning_rate': 0.012693089228250284, 'depth': 6, 'l2_leaf_reg': 11.959603830191838, 'subsample': 0.8187787356776066, 'rsm': 0.9436063712881633, 'random_strength': 0.07742116473996247}. Best is trial 6 with value: 11.930558625612477.
# [I 2026-07-02 00:56:25,027] Trial 10 finished with value: 13.334600352976045 and parameters: {'pca_components': 16, 'learning_rate': 0.005090641565719821, 'depth': 10, 'l2_leaf_reg': 23.82900342041925, 'subsample': 0.6363434386005422, 'rsm': 0.5193625999805915, 'random_strength': 6.903717055434683}. Best is trial 6 with value: 11.930558625612477.
# [I 2026-07-02 00:56:40,089] Trial 11 finished with value: 11.590348287995303 and parameters: {'pca_components': 16, 'learning_rate': 0.027622939390798212, 'depth': 10, 'l2_leaf_reg': 1.038623001038828, 'subsample': 0.6453475553360349, 'rsm': 0.6084783733972711, 'random_strength': 0.0014517449845829068}. Best is trial 11 with value: 11.590348287995303.
# [I 2026-07-02 00:56:47,957] Trial 12 finished with value: 11.702540129624886 and parameters: {'pca_components': 16, 'learning_rate': 0.03198911665569651, 'depth': 10, 'l2_leaf_reg': 1.014564269357042, 'subsample': 0.6540009746770628, 'rsm': 0.6071858177994054, 'random_strength': 0.02168832725827691}. Best is trial 11 with value: 11.590348287995303.
# [I 2026-07-02 00:56:50,170] Trial 13 finished with value: 12.28012476704687 and parameters: {'pca_components': 16, 'learning_rate': 0.050457787252396455, 'depth': 10, 'l2_leaf_reg': 1.0506568230449016, 'subsample': 0.6360833161363578, 'rsm': 0.611744326288265, 'random_strength': 0.001377048161873639}. Best is trial 11 with value: 11.590348287995303.
# [I 2026-07-02 00:57:03,586] Trial 14 finished with value: 13.192258540024746 and parameters: {'pca_components': 64, 'learning_rate': 0.0271603492107678, 'depth': 9, 'l2_leaf_reg': 4.829259395410981, 'subsample': 0.6773281245611447, 'rsm': 0.6207774664901698, 'random_strength': 0.007675815790375234}. Best is trial 11 with value: 11.590348287995303.
# [I 2026-07-02 00:57:06,206] Trial 15 finished with value: 10.789426206530871 and parameters: {'pca_components': 16, 'learning_rate': 0.07100464460634467, 'depth': 8, 'l2_leaf_reg': 1.047744111785693, 'subsample': 0.6906666232410598, 'rsm': 0.6091873673748522, 'random_strength': 0.06277022107963025}. Best is trial 15 with value: 10.789426206530871.
# [I 2026-07-02 00:57:06,907] Trial 16 finished with value: 12.032640758916992 and parameters: {'pca_components': 16, 'learning_rate': 0.09738618023587231, 'depth': 7, 'l2_leaf_reg': 1.959791879944778, 'subsample': 0.7058688047573056, 'rsm': 0.582298169605199, 'random_strength': 0.22913275045852932}. Best is trial 15 with value: 10.789426206530871.
# [I 2026-07-02 00:57:08,774] Trial 17 finished with value: 12.159869267096965 and parameters: {'pca_components': 16, 'learning_rate': 0.06693509528293802, 'depth': 8, 'l2_leaf_reg': 2.2854879558822057, 'subsample': 0.9886332327975389, 'rsm': 0.6599362867984438, 'random_strength': 2.0471470403247136}. Best is trial 15 with value: 10.789426206530871.
# [I 2026-07-02 00:57:09,339] Trial 18 pruned. Pruned after validation-well validation
# [I 2026-07-02 00:57:11,756] Trial 19 finished with value: 11.771168519718406 and parameters: {'pca_components': 16, 'learning_rate': 0.018514587781869863, 'depth': 8, 'l2_leaf_reg': 5.10722335742197, 'subsample': 0.583845311507793, 'rsm': 0.5673837373708196, 'random_strength': 0.3233547957550212}. Best is trial 15 with value: 10.789426206530871.
# Tune id: 1f17586c-3a95-6832-9b57-9c260c0977a0
# Tune directory: /Users/locked15/Repos.localized/Python/Study/UUST/Course 3/Semester 2/Practice/sludge-utilities/apps/ml/ml-training_lab/output/gb/tuning/1f17586c-3a95-6832-9b57-9c260c0977a0
# Optuna summary saved to: /Users/locked15/Repos.localized/Python/Study/UUST/Course 3/Semester 2/Practice/sludge-utilities/apps/ml/ml-training_lab/output/gb/tuning/1f17586c-3a95-6832-9b57-9c260c0977a0/catboost_dataset_split_v1_summary.json
# Optuna trials saved to: /Users/locked15/Repos.localized/Python/Study/UUST/Course 3/Semester 2/Practice/sludge-utilities/apps/ml/ml-training_lab/output/gb/tuning/1f17586c-3a95-6832-9b57-9c260c0977a0/catboost_dataset_split_v1_trials.csv
# Optuna database: /Users/locked15/Repos.localized/Python/Study/UUST/Course 3/Semester 2/Practice/sludge-utilities/apps/ml/ml-training_lab/output/gb/tuning/1f17586c-3a95-6832-9b57-9c260c0977a0/catboost_dataset_split_v1.db
