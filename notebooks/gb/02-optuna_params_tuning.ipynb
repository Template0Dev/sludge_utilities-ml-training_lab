# %% [markdown]
# # CatBoost Optuna tuning
#
# This notebook defines paths and delegates tuning to the controller API.

# %%
from pathlib import Path
import sys

from pyprojroot import here

PROJECT_ROOT = Path(here())
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from ml_training_lab.controller.catboost_tuning_controller import tune_catboost  # noqa: E402
from ml_training_lab.presentation.requests import CatBoostRequest  # noqa: E402

# %%
CONFIG_PATH = PROJECT_ROOT / "config/gb_training.json"
BASE_DATASET_PATH = PROJECT_ROOT / "data/meta/interim/metadata_augmented.parquet"
EMBEDDING_DATASET_PATH = PROJECT_ROOT / "data/meta/processed/gb/metadata_dinov3_embeddings.parquet"

request = CatBoostRequest(
    project_root=PROJECT_ROOT,
    config_path=CONFIG_PATH,
    base_dataset_path=BASE_DATASET_PATH,
    embedding_dataset_path=EMBEDDING_DATASET_PATH,
)
request
# Out:
# CatBoostRequest(project_root=PosixPath('/Users/locked15/Repos.localized/Python/Study/UUST/Course 3/Semester 2/Practice/sludge-utilities/apps/ml/ml-training_lab'), config_path=PosixPath('/Users/locked15/Repos.localized/Python/Study/UUST/Course 3/Semester 2/Practice/sludge-utilities/apps/ml/ml-training_lab/config/gb_training.json'), base_dataset_path=PosixPath('/Users/locked15/Repos.localized/Python/Study/UUST/Course 3/Semester 2/Practice/sludge-utilities/apps/ml/ml-training_lab/data/meta/interim/metadata_augmented.parquet'), embedding_dataset_path=PosixPath('/Users/locked15/Repos.localized/Python/Study/UUST/Course 3/Semester 2/Practice/sludge-utilities/apps/ml/ml-training_lab/data/meta/processed/gb/metadata_dinov3_embeddings.parquet'))

# %%
result = tune_catboost(request)

print(f"Optuna summary saved to: {result.summary_path}")
print(f"Optuna trials saved to: {result.trials_path}")
print(f"Optuna database: {result.study_database_path}")
# Out:
# [I 2026-06-29 11:26:41,585] A new study created in RDB with name: catboost_target_well_v1
# [I 2026-06-29 11:26:42,996] Trial 0 finished with value: 9.305506193401008 and parameters: {'pca_components': 32, 'learning_rate': 0.015, 'depth': 5, 'l2_leaf_reg': 10.0, 'subsample': 0.8, 'rsm': 0.7, 'random_strength': 1.0}. Best is trial 0 with value: 9.305506193401008.
# [I 2026-06-29 11:26:45,668] Trial 1 finished with value: 9.006611811992668 and parameters: {'pca_components': 32, 'learning_rate': 0.007979118876474874, 'depth': 5, 'l2_leaf_reg': 1.218418650222176, 'subsample': 0.9330880728874675, 'rsm': 0.8005575058716043, 'random_strength': 0.6796578090758157}. Best is trial 1 with value: 9.006611811992668.
# [I 2026-06-29 11:26:48,232] Trial 2 finished with value: 9.184779151969996 and parameters: {'pca_components': 32, 'learning_rate': 0.008620446097910767, 'depth': 5, 'l2_leaf_reg': 2.8145092716060645, 'subsample': 0.762378215816119, 'rsm': 0.7159725093210578, 'random_strength': 0.014618962793704969}. Best is trial 1 with value: 9.006611811992668.
# [I 2026-06-29 11:26:52,511] Trial 3 finished with value: 9.512517104668218 and parameters: {'pca_components': 16, 'learning_rate': 0.019603369861210685, 'depth': 9, 'l2_leaf_reg': 1.9721610970573997, 'subsample': 0.7571172192068059, 'rsm': 0.7962072844310213, 'random_strength': 0.0015339162591163618}. Best is trial 1 with value: 9.006611811992668.
# [I 2026-06-29 11:27:00,055] Trial 4 finished with value: 11.036349842129956 and parameters: {'pca_components': 128, 'learning_rate': 0.09021655603568132, 'depth': 9, 'l2_leaf_reg': 2.8180680291847233, 'subsample': 0.5488360570031919, 'rsm': 0.8421165132560784, 'random_strength': 0.057624872164786005}. Best is trial 1 with value: 9.006611811992668.
# [I 2026-06-29 11:27:11,943] Trial 5 pruned. Pruned after target-well validation
# [I 2026-06-29 11:27:19,449] Trial 6 pruned. Pruned after target-well validation
# [I 2026-06-29 11:27:30,948] Trial 7 pruned. Pruned after target-well validation
# [I 2026-06-29 11:28:02,926] Trial 8 pruned. Pruned after target-well validation
# [I 2026-06-29 11:28:03,703] Trial 9 finished with value: 9.117498965487068 and parameters: {'pca_components': 16, 'learning_rate': 0.012693089228250284, 'depth': 6, 'l2_leaf_reg': 11.959603830191838, 'subsample': 0.8187787356776066, 'rsm': 0.9436063712881633, 'random_strength': 0.07742116473996247}. Best is trial 1 with value: 9.006611811992668.
# [I 2026-06-29 11:28:05,763] Trial 10 pruned. Pruned after target-well validation
# [I 2026-06-29 11:28:07,505] Trial 11 pruned. Pruned after target-well validation
# [I 2026-06-29 11:28:13,451] Trial 12 pruned. Pruned after target-well validation
# [I 2026-06-29 11:28:14,574] Trial 13 pruned. Pruned after target-well validation
# [I 2026-06-29 11:28:16,257] Trial 14 finished with value: 8.873059543586548 and parameters: {'pca_components': 16, 'learning_rate': 0.007861760119900444, 'depth': 6, 'l2_leaf_reg': 1.0408836226004916, 'subsample': 0.6538712106961276, 'rsm': 0.6207774664901698, 'random_strength': 0.10790400074152012}. Best is trial 14 with value: 8.873059543586548.
# [I 2026-06-29 11:28:20,192] Trial 15 finished with value: 8.853761607038974 and parameters: {'pca_components': 16, 'learning_rate': 0.00713045628020294, 'depth': 7, 'l2_leaf_reg': 1.048909047445915, 'subsample': 0.672329017139718, 'rsm': 0.609702823553011, 'random_strength': 0.30239170896754763}. Best is trial 15 with value: 8.853761607038974.
# [I 2026-06-29 11:28:24,053] Trial 16 finished with value: 8.977060574999635 and parameters: {'pca_components': 16, 'learning_rate': 0.006558512945454901, 'depth': 7, 'l2_leaf_reg': 1.047925518461094, 'subsample': 0.6909982724187764, 'rsm': 0.6043193764988799, 'random_strength': 0.20200058548020378}. Best is trial 15 with value: 8.853761607038974.
# [I 2026-06-29 11:28:28,376] Trial 17 finished with value: 8.994460414873041 and parameters: {'pca_components': 16, 'learning_rate': 0.009375683578260267, 'depth': 7, 'l2_leaf_reg': 1.009856522066674, 'subsample': 0.6441190326385542, 'rsm': 0.6108600579796771, 'random_strength': 0.03287229523690311}. Best is trial 15 with value: 8.853761607038974.
# [I 2026-06-29 11:28:30,353] Trial 18 pruned. Pruned after target-well validation
# [I 2026-06-29 11:28:33,166] Trial 19 pruned. Pruned after target-well validation
# [I 2026-06-29 11:28:34,704] Trial 20 pruned. Pruned after target-well validation
# [I 2026-06-29 11:28:38,010] Trial 21 finished with value: 8.903223417912368 and parameters: {'pca_components': 16, 'learning_rate': 0.006270969949484728, 'depth': 7, 'l2_leaf_reg': 1.0384961013817575, 'subsample': 0.702035893340453, 'rsm': 0.6122591495509572, 'random_strength': 0.2078222034447669}. Best is trial 15 with value: 8.853761607038974.
# [I 2026-06-29 11:28:42,137] Trial 22 finished with value: 8.984433928904197 and parameters: {'pca_components': 16, 'learning_rate': 0.006243777342322153, 'depth': 7, 'l2_leaf_reg': 1.3225988659903656, 'subsample': 0.7144840557675811, 'rsm': 0.6463370661171335, 'random_strength': 0.25197054625499515}. Best is trial 15 with value: 8.853761607038974.
# [I 2026-06-29 11:28:45,558] Trial 23 finished with value: 8.938304551407159 and parameters: {'pca_components': 16, 'learning_rate': 0.007331194745918324, 'depth': 7, 'l2_leaf_reg': 1.5409128959692882, 'subsample': 0.6200392464368687, 'rsm': 0.5693849697152994, 'random_strength': 0.09683331972147854}. Best is trial 15 with value: 8.853761607038974.
# [I 2026-06-29 11:28:49,761] Trial 24 pruned. Pruned after target-well validation
# [I 2026-06-29 11:28:51,437] Trial 25 pruned. Pruned after target-well validation
# [I 2026-06-29 11:28:52,196] Trial 26 finished with value: 8.755679906591535 and parameters: {'pca_components': 16, 'learning_rate': 0.013171827584430777, 'depth': 5, 'l2_leaf_reg': 1.4255834186311662, 'subsample': 0.5660841385785127, 'rsm': 0.6407765816216827, 'random_strength': 0.15815262952169504}. Best is trial 26 with value: 8.755679906591535.
# [I 2026-06-29 11:28:52,894] Trial 27 finished with value: 8.715955577051 and parameters: {'pca_components': 16, 'learning_rate': 0.013759302872074467, 'depth': 5, 'l2_leaf_reg': 4.116257119500792, 'subsample': 0.501640093062105, 'rsm': 0.6602797354946714, 'random_strength': 0.05497278724363028}. Best is trial 27 with value: 8.715955577051.
# [I 2026-06-29 11:28:53,874] Trial 28 pruned. Pruned after target-well validation
# [I 2026-06-29 11:28:57,841] Trial 29 pruned. Pruned after target-well validation
# [I 2026-06-29 11:28:58,511] Trial 30 pruned. Pruned after target-well validation
# [I 2026-06-29 11:28:59,612] Trial 31 finished with value: 8.801838729254325 and parameters: {'pca_components': 16, 'learning_rate': 0.010264938260087663, 'depth': 5, 'l2_leaf_reg': 1.4530072894823265, 'subsample': 0.5950662999560389, 'rsm': 0.641896008073197, 'random_strength': 0.11697459377784898}. Best is trial 27 with value: 8.715955577051.
# [I 2026-06-29 11:29:00,367] Trial 32 finished with value: 8.60170393524598 and parameters: {'pca_components': 16, 'learning_rate': 0.013895406201394754, 'depth': 5, 'l2_leaf_reg': 7.671959660760385, 'subsample': 0.5824131016865502, 'rsm': 0.691655228022227, 'random_strength': 0.14384001886100276}. Best is trial 32 with value: 8.60170393524598.
# [I 2026-06-29 11:29:01,304] Trial 33 finished with value: 8.783184200468122 and parameters: {'pca_components': 16, 'learning_rate': 0.014692471782390177, 'depth': 5, 'l2_leaf_reg': 8.549153648119495, 'subsample': 0.5784874127033345, 'rsm': 0.7502644526802322, 'random_strength': 0.022158301207778782}. Best is trial 32 with value: 8.60170393524598.
# [I 2026-06-29 11:29:02,499] Trial 34 pruned. Pruned after target-well validation
# [I 2026-06-29 11:29:03,282] Trial 35 finished with value: 8.942093270761916 and parameters: {'pca_components': 16, 'learning_rate': 0.021704653006254345, 'depth': 5, 'l2_leaf_reg': 7.744398322308572, 'subsample': 0.523753577445855, 'rsm': 0.7049788188510674, 'random_strength': 0.00588984645903667}. Best is trial 32 with value: 8.60170393524598.
# [I 2026-06-29 11:29:03,836] Trial 36 finished with value: 8.941060113564786 and parameters: {'pca_components': 16, 'learning_rate': 0.01701217634919324, 'depth': 4, 'l2_leaf_reg': 16.279070507851568, 'subsample': 0.5666400180831274, 'rsm': 0.7999003311236816, 'random_strength': 0.059085138113766526}. Best is trial 32 with value: 8.60170393524598.
# [I 2026-06-29 11:29:05,753] Trial 37 pruned. Pruned after target-well validation
# [I 2026-06-29 11:29:07,925] Trial 38 pruned. Pruned after target-well validation
# [I 2026-06-29 11:29:08,406] Trial 39 pruned. Pruned after target-well validation
# [I 2026-06-29 11:29:09,742] Trial 40 finished with value: 8.90746672436847 and parameters: {'pca_components': 16, 'learning_rate': 0.013636746323033534, 'depth': 5, 'l2_leaf_reg': 18.110264928417973, 'subsample': 0.524445463060827, 'rsm': 0.778671283615696, 'random_strength': 0.058351244334208074}. Best is trial 32 with value: 8.60170393524598.
# [I 2026-06-29 11:29:11,041] Trial 41 finished with value: 8.694685422732928 and parameters: {'pca_components': 16, 'learning_rate': 0.010859369578754333, 'depth': 5, 'l2_leaf_reg': 2.3520184588166835, 'subsample': 0.6047392637931212, 'rsm': 0.6397892758555777, 'random_strength': 0.1501004080843442}. Best is trial 32 with value: 8.60170393524598.
# [I 2026-06-29 11:29:11,798] Trial 42 finished with value: 8.747331252135602 and parameters: {'pca_components': 16, 'learning_rate': 0.01115358417929444, 'depth': 5, 'l2_leaf_reg': 3.1172377718859905, 'subsample': 0.6198838009480594, 'rsm': 0.6760937983983631, 'random_strength': 0.16682901085814947}. Best is trial 32 with value: 8.60170393524598.
# [I 2026-06-29 11:29:12,968] Trial 43 finished with value: 8.778645410686687 and parameters: {'pca_components': 16, 'learning_rate': 0.01171194663461226, 'depth': 6, 'l2_leaf_reg': 2.438970175794935, 'subsample': 0.6163694123112416, 'rsm': 0.6775603015359223, 'random_strength': 0.16558780168191928}. Best is trial 32 with value: 8.60170393524598.
# [I 2026-06-29 11:29:20,937] Trial 44 pruned. Pruned after target-well validation
# [I 2026-06-29 11:29:21,539] Trial 45 finished with value: 8.849611680883095 and parameters: {'pca_components': 16, 'learning_rate': 0.01101953441286326, 'depth': 4, 'l2_leaf_reg': 3.009042734711248, 'subsample': 0.5550029554523715, 'rsm': 0.6924088393958354, 'random_strength': 0.08013959254426528}. Best is trial 32 with value: 8.60170393524598.
# [I 2026-06-29 11:29:25,358] Trial 46 pruned. Pruned after target-well validation
# [I 2026-06-29 11:29:26,388] Trial 47 finished with value: 8.768882871144477 and parameters: {'pca_components': 16, 'learning_rate': 0.009949339244098066, 'depth': 5, 'l2_leaf_reg': 4.885046697029011, 'subsample': 0.6163850304700695, 'rsm': 0.7256748960816812, 'random_strength': 0.1743723022597719}. Best is trial 32 with value: 8.60170393524598.
# [I 2026-06-29 11:29:27,815] Trial 48 finished with value: 8.856597449401484 and parameters: {'pca_components': 32, 'learning_rate': 0.012566374992939645, 'depth': 4, 'l2_leaf_reg': 1.8297660338283404, 'subsample': 0.5231548607048164, 'rsm': 0.6673416020475514, 'random_strength': 0.280943970321224}. Best is trial 32 with value: 8.60170393524598.
# [I 2026-06-29 11:29:29,054] Trial 49 pruned. Pruned after target-well validation
# Optuna summary saved to: /Users/locked15/Repos.localized/Python/Study/UUST/Course 3/Semester 2/Practice/sludge-utilities/apps/ml/ml-training_lab/output/gb/tuning/catboost_target_well_v1_summary.json
# Optuna trials saved to: /Users/locked15/Repos.localized/Python/Study/UUST/Course 3/Semester 2/Practice/sludge-utilities/apps/ml/ml-training_lab/output/gb/tuning/catboost_target_well_v1_trials.csv
# Optuna database: /Users/locked15/Repos.localized/Python/Study/UUST/Course 3/Semester 2/Practice/sludge-utilities/apps/ml/ml-training_lab/output/gb/tuning/catboost_target_well_v1.db
